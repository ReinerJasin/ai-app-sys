# %% [markdown]
# <a href="https://colab.research.google.com/github/ReinerJasin/ai-app-sys/blob/main/Skin_problems_detection_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries Preparation

# %% [markdown]
# **Clone and Install YOLO V5 library provided by ultralytics on GitHub with some other libraries needed for this project**

# %%
# Clone and Install libraries
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt

# Import libraries
import torch 
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 22.7/78.2 GB disk)

# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# ## Mount google drive

# %% [markdown]
# **Mount Google Drive to connect the account where the dataset is located**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download Dataset

# %% [markdown]
# **We're going to make URL endpoint to make it easier to get the file from the google drive directory**

# %%
# Import libraries
import os

# Make URL endpoint for every part of the dataset image and labels
root_dir = '/content/drive/MyDrive/AI_final_project/'

train_img_dir = os.path.join(root_dir, 'images/train/')
val_img_dir = os.path.join(root_dir, 'images/val/')

# path for dataset with 6 labels/classes
# train_lbl_dir = os.path.join(root_dir, 'labels/train/')
# val_lbl_dir = os.path.join(root_dir, 'labels/val/')

# path for dataset with 4 labels/classes
# train_lbl_dir = os.path.join(root_dir, 'labels_1/train/')
# val_lbl_dir = os.path.join(root_dir, 'labels_1/val/')

# path for dataset with 1 label/classes
train_lbl_dir = os.path.join(root_dir, 'labels_2/train/')
val_lbl_dir = os.path.join(root_dir, 'labels_2/val/')

# %% [markdown]
# **Get all the file inside the URL to be shown as an example on the next step**

# %%
train_img = os.listdir(train_img_dir)     # url : /content/drive/MyDrive/AI_final_project/images/train/...
val_img = os.listdir(val_img_dir)         # url : /content/drive/MyDrive/AI_final_project/images/val/...
train_lbl = os.listdir(train_lbl_dir)     # url : /content/drive/MyDrive/AI_final_project/labels/train/...
val_lbl = os.listdir(val_lbl_dir)         # url : /content/drive/MyDrive/AI_final_project/labels/val/...

# Sort the result
train_img = sorted(train_img)
val_img = sorted(val_img)
train_lbl = sorted(train_lbl)
val_lbl = sorted(val_lbl)

# %% [markdown]
# **Using matplotlib, we're going to show a sample image from the train and val dataset**

# %% [markdown]
# **a. Train Image**

# %%
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# load the image
img = plt.imread(train_img_dir + train_img[4])
height, width, channels = img.shape

# create a figure and axis
fig, ax = plt.subplots(1, figsize=(20, 12))

# show the image
ax.imshow(img)

# read the text file
with open(train_lbl_dir + train_lbl[4], 'r') as f:
    lines = f.readlines()

# parse the text file
for line in lines:
    # split the line into values
    values = line.split()

    # get the class and bounding box coordinates
    class_name = values[0]
    x_min = float(values[1]) * width - 25
    y_min = float(values[2]) * height - 25
    x_max = float(values[3]) * width
    y_max = float(values[4]) * height

    # create a Rectangle patch
    rect = patches.Rectangle((x_min, y_min), x_max, y_max, linewidth=1, edgecolor='r', facecolor='none')
    
    # add the patch to the axis
    ax.add_patch(rect)

# show the figure
plt.title(train_img[4])
plt.show()

# %% [markdown]
# **b. Validation Image**

# %%
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# load the image
img = plt.imread(val_img_dir + val_img[0])
height, width, channels = img.shape

# create a figure and axis
fig, ax = plt.subplots(1, figsize=(20, 12))

# show the image
ax.imshow(img)

# read the text file
with open(val_lbl_dir + val_lbl[0], 'r') as f:
    lines = f.readlines()

# parse the text file
for line in lines:
    # split the line into values
    values = line.split()

    # get the class and bounding box coordinates
    class_name = values[0]
    x_min = float(values[1]) * width - 25
    y_min = float(values[2]) * height - 25
    x_max = float(values[3]) * width
    y_max = float(values[4]) * height

    # create a Rectangle patch
    rect = patches.Rectangle((x_min, y_min), x_max, y_max, linewidth=1, edgecolor='r', facecolor='none')
    
    # add the patch to the axis
    ax.add_patch(rect)

# show the figure
plt.title(val_img[0])
plt.show()

# %% [markdown]
# # Train Model

# %% [markdown]
# Upload the custom_data.yaml data inside the data /yolov5/data folder

# %% [markdown]
# custom-data.yaml :
#
# ```
# # change the path depends on the google drive directory
# path: /content/drive/MyDrive/AI_final_project      # Path to main folder of train and val
# train: images/train                                # train images
# val: images/val                                    # val images
# test:  # test images (optional)
#
# # List all classes and make sure the number is match with the YOLO V5 annotation index
# names:
#   0: acne
#   1: blackhead
#   2: dark circles
#   3: dry skin
#   4: enlarged pores
#   5: wrinkles
#
# ```

# %% [markdown]
# **Train the YOLO v5 model using train.py python file provided by Ultralytics**

# %% [markdown]
# **hyperparameter of this training process:**<br>
# batch : 2<br>
# epochs : 60<br>
# total classes : 6

# %%
# Train YOLOv5s
# !python train.py --img 640 --batch 2 --epochs 60 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=6
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     29667  models.yolo.Detect                      [6, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7035811 parameters, 7035811 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/.shortcut-targets-by-id/19XjDTFJT0k7v8sojJZxdqHoyMHTELCPv/AI final project/labels/train.cache... 549 images, 0 backgrounds, 0 corrupt: 100% 549/549 [00:00<?, ?it/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/19XjDTFJT0k7v8sojJZxdqHoyMHTELCPv/AI final project/labels/val.cache... 138 images, 0 backgrounds, 0 corrupt: 100% 138/138 [00:00<?, ?it/s]
#
# AutoAnchor: 3.39 anchors/target, 0.997 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/59     0.505G     0.1248    0.05229    0.04972         58        640:  71% 194/275 [03:42<01:27,  1.08s/it]Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/tqdm/std.py", line 1195, in __iter__
#     for obj in iterable:
#   File "/content/yolov5/utils/dataloaders.py", line 171, in __iter__
#     yield next(self.iterator)
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 681, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1359, in _next_data
#     idx, data = self._get_data()
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1315, in _get_data
#     success, data = self._try_get_data()
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1163, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.8/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train.py", line 633, in <module>
#     main(opt)
#   File "train.py", line 527, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "train.py", line 282, in train
#     for i, (imgs, targets, paths, _) in pbar:  # batch -------------------------------------------------------------
#   File "/usr/local/lib/python3.8/dist-packages/tqdm/std.py", line 1210, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.8/dist-packages/tqdm/std.py", line 1289, in close
#     self._decr_instances(self)
#   File "/usr/local/lib/python3.8/dist-packages/tqdm/std.py", line 601, in _decr_instances
#     if not instance.gui:
# KeyboardInterrupt
# ^C

# %% [markdown]
# # Validate Model (Optional)

# %% [markdown]
# **Validate the YOLO v5 model using train.py python file provided by Ultralytics**

# %% [markdown]
# **--half** is used to apply the FP16 half-precision inference on the validation process
# <br><br>
# **Some other parameter :**
# <br>
# **--verbose** is used to report the mAP by class <br>
# **--save-txt** is used to save the result to a .txt file <br>
# **--save-conf** is used to save the confidences in --save-txt labels

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights /content/yolov5/runs/train/exp/weights/best.pt --data custom_data.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/custom_data.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/19XjDTFJT0k7v8sojJZxdqHoyMHTELCPv/AI final project/labels/val.cache... 138 images, 0 backgrounds, 0 corrupt: 100% 138/138 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:29<00:00,  5.85s/it]
#                    all        138       2005      0.689       0.13      0.076      0.026
#                   acne        138       1658      0.182      0.252      0.119     0.0304
#           dark circles        138         78      0.265      0.397      0.199     0.0818
#               dry skin        138          2          1          0          0          0
#         enlarged pores        138        120          1          0     0.0624      0.018
#               wrinkles        138        147          1          0          0          0
# Speed: 1.8ms pre-process, 6.9ms inference, 11.8ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# # Make prediction with the model result

# %% [markdown]
# ## Detect from a video file

# %% [markdown]
# **Upload your video.mp4 or any other video file**

# %% [markdown]
# **Notes:**
# <br>
# **--conf** is used as a treshold to make the prediction. If the confidence is above 0.25, the bounding box will be shown on the video.
# <br>
# **--save-txt** is used to save the text output of all the detected object on the video.

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --save-txt --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/379) /content/video.mp4: 640x384 2 acnes, 12.1ms
# video 1/1 (2/379) /content/video.mp4: 640x384 1 acne, 9.5ms
# video 1/1 (3/379) /content/video.mp4: 640x384 2 acnes, 1 dark circles, 9.5ms
# video 1/1 (4/379) /content/video.mp4: 640x384 2 acnes, 9.5ms
# video 1/1 (5/379) /content/video.mp4: 640x384 1 acne, 9.5ms
# video 1/1 (6/379) /content/video.mp4: 640x384 2 acnes, 9.5ms
# video 1/1 (7/379) /content/video.mp4: 640x384 3 acnes, 9.5ms
# video 1/1 (8/379) /content/video.mp4: 640x384 2 acnes, 9.5ms
# video 1/1 (9/379) /content/video.mp4: 640x384 2 acnes, 9.5ms
# video 1/1 (10/379) /content/video.mp4: 640x384 1 acne, 9.4ms
# video 1/1 (11/379) /content/video.mp4: 640x384 (no detections), 9.4ms
# video 1/1 (12/379) /content/video.mp4: 640x384 3 acnes, 8.9ms
# video 1/1 (13/379) /content/video.mp4: 640x384 2 acnes, 7.9ms
# video 1/1 (14/379) /content/video.mp4: 640x384 3 acnes, 7.9ms
# video 1/1 (15/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (16/379) /content/video.mp4: 640x384 3 acnes, 8.0ms
# video 1/1 (17/379) /content/video.mp4: 640x384 3 acnes, 7.9ms
# video 1/1 (18/379) /content/video.mp4: 640x384 2 acnes, 7.9ms
# video 1/1 (19/379) /content/video.mp4: 640x384 2 acnes, 7.9ms
# video 1/1 (20/379) /content/video.mp4: 640x384 2 acnes, 12.0ms
# video 1/1 (21/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (22/379) /content/video.mp4: 640x384 (no detections), 8.4ms
# video 1/1 (23/379) /content/video.mp4: 640x384 3 acnes, 7.6ms
# video 1/1 (24/379) /content/video.mp4: 640x384 2 acnes, 1 dark circles, 7.7ms
# video 1/1 (25/379) /content/video.mp4: 640x384 2 acnes, 7.3ms
# video 1/1 (26/379) /content/video.mp4: 640x384 3 acnes, 7.5ms
# video 1/1 (27/379) /content/video.mp4: 640x384 2 acnes, 7.7ms
# video 1/1 (28/379) /content/video.mp4: 640x384 3 acnes, 7.5ms
# video 1/1 (29/379) /content/video.mp4: 640x384 2 acnes, 7.5ms
# video 1/1 (30/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (31/379) /content/video.mp4: 640x384 2 acnes, 8.0ms
# video 1/1 (32/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (33/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (34/379) /content/video.mp4: 640x384 2 acnes, 8.1ms
# video 1/1 (35/379) /content/video.mp4: 640x384 2 acnes, 7.7ms
# video 1/1 (36/379) /content/video.mp4: 640x384 2 acnes, 7.3ms
# video 1/1 (37/379) /content/video.mp4: 640x384 2 acnes, 11.8ms
# video 1/1 (38/379) /content/video.mp4: 640x384 2 acnes, 7.8ms
# video 1/1 (39/379) /content/video.mp4: 640x384 3 acnes, 7.9ms
# video 1/1 (40/379) /content/video.mp4: 640x384 3 acnes, 7.8ms
# video 1/1 (41/379) /content/video.mp4: 640x384 5 acnes, 7.7ms
# video 1/1 (42/379) /content/video.mp4: 640x384 1 acne, 9.1ms
# video 1/1 (43/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (44/379) /content/video.mp4: 640x384 3 acnes, 7.8ms
# video 1/1 (45/379) /content/video.mp4: 640x384 3 acnes, 7.8ms
# video 1/1 (46/379) /content/video.mp4: 640x384 3 acnes, 7.7ms
# video 1/1 (47/379) /content/video.mp4: 640x384 4 acnes, 9.2ms
# video 1/1 (48/379) /content/video.mp4: 640x384 3 acnes, 8.6ms
# video 1/1 (49/379) /content/video.mp4: 640x384 3 acnes, 7.7ms
# video 1/1 (50/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (51/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (52/379) /content/video.mp4: 640x384 1 acne, 9.6ms
# video 1/1 (53/379) /content/video.mp4: 640x384 3 acnes, 8.3ms
# video 1/1 (54/379) /content/video.mp4: 640x384 3 acnes, 8.2ms
# video 1/1 (55/379) /content/video.mp4: 640x384 1 acne, 7.6ms
# video 1/1 (56/379) /content/video.mp4: 640x384 4 acnes, 7.6ms
# video 1/1 (57/379) /content/video.mp4: 640x384 4 acnes, 7.4ms
# video 1/1 (58/379) /content/video.mp4: 640x384 2 acnes, 8.2ms
# video 1/1 (59/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (60/379) /content/video.mp4: 640x384 2 acnes, 8.0ms
# video 1/1 (61/379) /content/video.mp4: 640x384 2 acnes, 7.8ms
# video 1/1 (62/379) /content/video.mp4: 640x384 2 acnes, 7.5ms
# video 1/1 (63/379) /content/video.mp4: 640x384 1 acne, 7.5ms
# video 1/1 (64/379) /content/video.mp4: 640x384 1 acne, 8.3ms
# video 1/1 (65/379) /content/video.mp4: 640x384 1 acne, 7.5ms
# video 1/1 (66/379) /content/video.mp4: 640x384 3 acnes, 8.1ms
# video 1/1 (67/379) /content/video.mp4: 640x384 1 acne, 8.4ms
# video 1/1 (68/379) /content/video.mp4: 640x384 1 acne, 8.1ms
# video 1/1 (69/379) /content/video.mp4: 640x384 2 acnes, 9.1ms
# video 1/1 (70/379) /content/video.mp4: 640x384 (no detections), 8.5ms
# video 1/1 (71/379) /content/video.mp4: 640x384 (no detections), 8.4ms
# video 1/1 (72/379) /content/video.mp4: 640x384 (no detections), 8.5ms
# video 1/1 (73/379) /content/video.mp4: 640x384 (no detections), 8.3ms
# video 1/1 (74/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (75/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (76/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (77/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (78/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (79/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (80/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (81/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (82/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (83/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (84/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (85/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (86/379) /content/video.mp4: 640x384 1 acne, 10.8ms
# video 1/1 (87/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (88/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (89/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (90/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (91/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (92/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (93/379) /content/video.mp4: 640x384 (no detections), 8.2ms
# video 1/1 (94/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (95/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (96/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (97/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (98/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (99/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (100/379) /content/video.mp4: 640x384 (no detections), 8.3ms
# video 1/1 (101/379) /content/video.mp4: 640x384 (no detections), 8.2ms
# video 1/1 (102/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (103/379) /content/video.mp4: 640x384 (no detections), 8.6ms
# video 1/1 (104/379) /content/video.mp4: 640x384 (no detections), 8.2ms
# video 1/1 (105/379) /content/video.mp4: 640x384 (no detections), 8.3ms
# video 1/1 (106/379) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (107/379) /content/video.mp4: 640x384 1 acne, 7.6ms
# video 1/1 (108/379) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (109/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (110/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (111/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (112/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (113/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (114/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (115/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (116/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (117/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (118/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (119/379) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (120/379) /content/video.mp4: 640x384 (no detections), 8.2ms
# video 1/1 (121/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (122/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (123/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (124/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (125/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (126/379) /content/video.mp4: 640x384 (no detections), 9.3ms
# video 1/1 (127/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (128/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (129/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (130/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (131/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (132/379) /content/video.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (133/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (134/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (135/379) /content/video.mp4: 640x384 (no detections), 10.1ms
# video 1/1 (136/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (137/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (138/379) /content/video.mp4: 640x384 (no detections), 11.9ms
# video 1/1 (139/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (140/379) /content/video.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (141/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (142/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (143/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (144/379) /content/video.mp4: 640x384 (no detections), 8.5ms
# video 1/1 (145/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (146/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (147/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (148/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (149/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (150/379) /content/video.mp4: 640x384 (no detections), 8.6ms
# video 1/1 (151/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (152/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (153/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (154/379) /content/video.mp4: 640x384 1 acne, 8.2ms
# video 1/1 (155/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (156/379) /content/video.mp4: 640x384 1 acne, 10.3ms
# video 1/1 (157/379) /content/video.mp4: 640x384 2 acnes, 7.9ms
# video 1/1 (158/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (159/379) /content/video.mp4: 640x384 3 acnes, 7.7ms
# video 1/1 (160/379) /content/video.mp4: 640x384 2 acnes, 7.7ms
# video 1/1 (161/379) /content/video.mp4: 640x384 3 acnes, 8.8ms
# video 1/1 (162/379) /content/video.mp4: 640x384 3 acnes, 8.4ms
# video 1/1 (163/379) /content/video.mp4: 640x384 1 acne, 8.5ms
# video 1/1 (164/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (165/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (166/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (167/379) /content/video.mp4: 640x384 (no detections), 8.2ms
# video 1/1 (168/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (169/379) /content/video.mp4: 640x384 1 acne, 12.5ms
# video 1/1 (170/379) /content/video.mp4: 640x384 1 acne, 1 dark circles, 8.0ms
# video 1/1 (171/379) /content/video.mp4: 640x384 5 acnes, 7.9ms
# video 1/1 (172/379) /content/video.mp4: 640x384 8 acnes, 7.9ms
# video 1/1 (173/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (174/379) /content/video.mp4: 640x384 1 acne, 1 dark circles, 7.7ms
# video 1/1 (175/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (176/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (177/379) /content/video.mp4: 640x384 6 acnes, 8.3ms
# video 1/1 (178/379) /content/video.mp4: 640x384 5 acnes, 1 dark circles, 8.1ms
# video 1/1 (179/379) /content/video.mp4: 640x384 7 acnes, 7.8ms
# video 1/1 (180/379) /content/video.mp4: 640x384 5 acnes, 7.7ms
# video 1/1 (181/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (182/379) /content/video.mp4: 640x384 3 acnes, 7.7ms
# video 1/1 (183/379) /content/video.mp4: 640x384 2 acnes, 9.4ms
# video 1/1 (184/379) /content/video.mp4: 640x384 1 acne, 1 dark circles, 7.8ms
# video 1/1 (185/379) /content/video.mp4: 640x384 2 acnes, 7.8ms
# video 1/1 (186/379) /content/video.mp4: 640x384 4 acnes, 7.9ms
# video 1/1 (187/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (188/379) /content/video.mp4: 640x384 1 acne, 11.1ms
# video 1/1 (189/379) /content/video.mp4: 640x384 3 acnes, 7.5ms
# video 1/1 (190/379) /content/video.mp4: 640x384 4 acnes, 7.9ms
# video 1/1 (191/379) /content/video.mp4: 640x384 3 acnes, 7.8ms
# video 1/1 (192/379) /content/video.mp4: 640x384 3 acnes, 7.4ms
# video 1/1 (193/379) /content/video.mp4: 640x384 4 acnes, 8.2ms
# video 1/1 (194/379) /content/video.mp4: 640x384 3 acnes, 8.3ms
# video 1/1 (195/379) /content/video.mp4: 640x384 3 acnes, 7.8ms
# video 1/1 (196/379) /content/video.mp4: 640x384 2 acnes, 7.5ms
# video 1/1 (197/379) /content/video.mp4: 640x384 2 acnes, 7.8ms
# video 1/1 (198/379) /content/video.mp4: 640x384 3 acnes, 7.6ms
# video 1/1 (199/379) /content/video.mp4: 640x384 4 acnes, 8.1ms
# video 1/1 (200/379) /content/video.mp4: 640x384 2 acnes, 7.9ms
# video 1/1 (201/379) /content/video.mp4: 640x384 3 acnes, 7.5ms
# video 1/1 (202/379) /content/video.mp4: 640x384 3 acnes, 8.1ms
# video 1/1 (203/379) /content/video.mp4: 640x384 1 acne, 8.1ms
# video 1/1 (204/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (205/379) /content/video.mp4: 640x384 4 acnes, 7.8ms
# video 1/1 (206/379) /content/video.mp4: 640x384 4 acnes, 8.0ms
# video 1/1 (207/379) /content/video.mp4: 640x384 4 acnes, 7.5ms
# video 1/1 (208/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (209/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (210/379) /content/video.mp4: 640x384 1 acne, 8.5ms
# video 1/1 (211/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (212/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (213/379) /content/video.mp4: 640x384 1 acne, 7.5ms
# video 1/1 (214/379) /content/video.mp4: 640x384 2 acnes, 7.5ms
# video 1/1 (215/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (216/379) /content/video.mp4: 640x384 2 acnes, 8.2ms
# video 1/1 (217/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (218/379) /content/video.mp4: 640x384 (no detections), 10.6ms
# video 1/1 (219/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (220/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (221/379) /content/video.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (222/379) /content/video.mp4: 640x384 (no detections), 11.1ms
# video 1/1 (223/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (224/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (225/379) /content/video.mp4: 640x384 (no detections), 11.8ms
# video 1/1 (226/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (227/379) /content/video.mp4: 640x384 (no detections), 8.7ms
# video 1/1 (228/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (229/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (230/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (231/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (232/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (233/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (234/379) /content/video.mp4: 640x384 2 acnes, 8.7ms
# video 1/1 (235/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (236/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (237/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (238/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (239/379) /content/video.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (240/379) /content/video.mp4: 640x384 (no detections), 12.0ms
# video 1/1 (241/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (242/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (243/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (244/379) /content/video.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (245/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (246/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (247/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (248/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (249/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (250/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (251/379) /content/video.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (252/379) /content/video.mp4: 640x384 1 acne, 8.1ms
# video 1/1 (253/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (254/379) /content/video.mp4: 640x384 2 acnes, 7.4ms
# video 1/1 (255/379) /content/video.mp4: 640x384 2 acnes, 11.1ms
# video 1/1 (256/379) /content/video.mp4: 640x384 1 acne, 8.3ms
# video 1/1 (257/379) /content/video.mp4: 640x384 1 acne, 9.8ms
# video 1/1 (258/379) /content/video.mp4: 640x384 1 acne, 8.1ms
# video 1/1 (259/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (260/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (261/379) /content/video.mp4: 640x384 1 acne, 7.6ms
# video 1/1 (262/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (263/379) /content/video.mp4: 640x384 2 acnes, 8.6ms
# video 1/1 (264/379) /content/video.mp4: 640x384 2 acnes, 8.1ms
# video 1/1 (265/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (266/379) /content/video.mp4: 640x384 2 acnes, 7.9ms
# video 1/1 (267/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (268/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (269/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (270/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (271/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (272/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (273/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (274/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (275/379) /content/video.mp4: 640x384 (no detections), 11.5ms
# video 1/1 (276/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (277/379) /content/video.mp4: 640x384 6 acnes, 7.4ms
# video 1/1 (278/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (279/379) /content/video.mp4: 640x384 1 acne, 7.3ms
# video 1/1 (280/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (281/379) /content/video.mp4: 640x384 2 acnes, 7.4ms
# video 1/1 (282/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (283/379) /content/video.mp4: 640x384 1 acne, 7.4ms
# video 1/1 (284/379) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (285/379) /content/video.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (286/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (287/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (288/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (289/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (290/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (291/379) /content/video.mp4: 640x384 1 acne, 7.5ms
# video 1/1 (292/379) /content/video.mp4: 640x384 1 acne, 11.7ms
# video 1/1 (293/379) /content/video.mp4: 640x384 (no detections), 10.0ms
# video 1/1 (294/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (295/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (296/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (297/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (298/379) /content/video.mp4: 640x384 (no detections), 7.3ms
# video 1/1 (299/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (300/379) /content/video.mp4: 640x384 1 acne, 7.3ms
# video 1/1 (301/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (302/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (303/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (304/379) /content/video.mp4: 640x384 1 acne, 7.6ms
# video 1/1 (305/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (306/379) /content/video.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (307/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (308/379) /content/video.mp4: 640x384 1 acne, 7.3ms
# video 1/1 (309/379) /content/video.mp4: 640x384 1 acne, 7.5ms
# video 1/1 (310/379) /content/video.mp4: 640x384 1 acne, 7.6ms
# video 1/1 (311/379) /content/video.mp4: 640x384 (no detections), 9.9ms
# video 1/1 (312/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (313/379) /content/video.mp4: 640x384 1 acne, 7.4ms
# video 1/1 (314/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (315/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (316/379) /content/video.mp4: 640x384 4 acnes, 7.6ms
# video 1/1 (317/379) /content/video.mp4: 640x384 (no detections), 8.4ms
# video 1/1 (318/379) /content/video.mp4: 640x384 1 acne, 10.4ms
# video 1/1 (319/379) /content/video.mp4: 640x384 3 acnes, 7.7ms
# video 1/1 (320/379) /content/video.mp4: 640x384 2 acnes, 7.5ms
# video 1/1 (321/379) /content/video.mp4: 640x384 1 acne, 7.6ms
# video 1/1 (322/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (323/379) /content/video.mp4: 640x384 2 acnes, 8.1ms
# video 1/1 (324/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (325/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (326/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (327/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (328/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (329/379) /content/video.mp4: 640x384 2 acnes, 11.1ms
# video 1/1 (330/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (331/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (332/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (333/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (334/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (335/379) /content/video.mp4: 640x384 (no detections), 7.6ms
# video 1/1 (336/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (337/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (338/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (339/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (340/379) /content/video.mp4: 640x384 2 acnes, 7.6ms
# video 1/1 (341/379) /content/video.mp4: 640x384 4 acnes, 8.2ms
# video 1/1 (342/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (343/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (344/379) /content/video.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (345/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (346/379) /content/video.mp4: 640x384 (no detections), 11.1ms
# video 1/1 (347/379) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (348/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (349/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# video 1/1 (350/379) /content/video.mp4: 640x384 (no detections), 9.2ms
# video 1/1 (351/379) /content/video.mp4: 640x384 1 dark circles, 8.0ms
# video 1/1 (352/379) /content/video.mp4: 640x384 1 dark circles, 7.6ms
# video 1/1 (353/379) /content/video.mp4: 640x384 (no detections), 8.7ms
# video 1/1 (354/379) /content/video.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (355/379) /content/video.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (356/379) /content/video.mp4: 640x384 2 acnes, 7.7ms
# video 1/1 (357/379) /content/video.mp4: 640x384 3 acnes, 7.9ms
# video 1/1 (358/379) /content/video.mp4: 640x384 1 acne, 9.5ms
# video 1/1 (359/379) /content/video.mp4: 640x384 1 acne, 8.0ms
# video 1/1 (360/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (361/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (362/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (363/379) /content/video.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (364/379) /content/video.mp4: 640x384 1 acne, 8.1ms
# video 1/1 (365/379) /content/video.mp4: 640x384 1 acne, 7.8ms
# video 1/1 (366/379) /content/video.mp4: 640x384 1 acne, 7.7ms
# video 1/1 (367/379) /content/video.mp4: 640x384 5 acnes, 7.7ms
# video 1/1 (368/379) /content/video.mp4: 640x384 4 acnes, 7.7ms
# video 1/1 (369/379) /content/video.mp4: 640x384 3 acnes, 7.5ms
# video 1/1 (370/379) /content/video.mp4: 640x384 2 acnes, 7.9ms
# video 1/1 (371/379) /content/video.mp4: 640x384 2 acnes, 7.7ms
# video 1/1 (372/379) /content/video.mp4: 640x384 3 acnes, 7.9ms
# video 1/1 (373/379) /content/video.mp4: 640x384 2 acnes, 8.5ms
# video 1/1 (374/379) /content/video.mp4: 640x384 1 acne, 7.9ms
# video 1/1 (375/379) /content/video.mp4: 640x384 (no detections), 8.2ms
# video 1/1 (376/379) /content/video.mp4: 640x384 2 acnes, 7.8ms
# video 1/1 (377/379) /content/video.mp4: 640x384 2 acnes, 1 dark circles, 7.7ms
# video 1/1 (378/379) /content/video.mp4: 640x384 3 acnes, 1 dark circles, 7.9ms
# video 1/1 (379/379) /content/video.mp4: 640x384 (no detections), 7.9ms
# Speed: 0.4ms pre-process, 8.1ms inference, 0.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
# 207 labels saved to runs/detect/exp/labels

# %% [markdown]
# **Result example:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As you can see the result is saved to the runs/detect/exp(n) directory. The video can be downloaded and played to see the result.

# %% [markdown]
# ## Detect from a webcam (can only be run on jupyter notebook)

# %%
# !python detect.py --source 0 --weights runs/train/exp6/weights/best.pt
# Out:
# detect: weights=['runs/train/exp6/weights/best.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-18-gd7955fe Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# [ WARN:0@5.360] global /io/opencv/modules/videoio/src/cap_v4l.cpp (902) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# Traceback (most recent call last):
#   File "detect.py", line 259, in <module>
#     main(opt)
#   File "detect.py", line 254, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 104, in run
#     dataset = LoadStreams(source, img_size=imgsz, stride=stride, auto=pt, vid_stride=vid_stride)
#   File "/content/yolov5/utils/dataloaders.py", line 364, in __init__
#     assert cap.isOpened(), f'{st}Failed to open {s}'
# AssertionError: 1/1: 0... Failed to open 0
